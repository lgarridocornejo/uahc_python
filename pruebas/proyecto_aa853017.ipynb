# %%
# venv: uacademia >> aa853017

# %% [markdown]
# # Proyecto EDA
# ## Objetivos
#
# - Realizar un correcto análisis y tratamiento de los datos, el cuál permitirá preparar y limpiar los datos de la forma más adecuada.
# - Comprender la relevacia de las variables e identificará las variables más significativas que tienen mayor relación con el objetivo.
# - Comprender la correlación entre las variables y señalar gráficamente los valores atípicos en las distribuciones.
# - Eliminar valores faltantes, duplicados y atípicos de manera correcta, usando el modo más adecuado para su objetivo.
#
# ## Criterio de evaluación
# <table>
#   <thead>
#     <tr>
#       <th>P</th>
#       <th>Criterio</th>
#       <th>Destacado (5 pts)</th>
#       <th>Logrado (3 pts)</th>
#       <th>En desarrollo (2 pto)</th>
#       <th>Inicial (1 pts)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Análisis inicial, registros y columnas. Tipo de datos.</td>
#       <td>Indica el número de filas y columnas del dataframe.Indica además el nombre y tipo de dato de la columna</td>
#       <td>Indica el número de filas y columnas, e identifica el tipo de dato. </td>
#       <td>Menciona parcialmente filas/columnas o tipo de datos.</td>
#       <td>No identifica adecuadamente filas, columnas ni tipo de datos.</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Completitud</td>
#       <td>Señala el porcentaje completo de datos y realiza gráfico de la completitud total.</td>
#       <td>Señala el porcentaje de datos completos</td>
#       <td>Señala parcialmente la completitud.</td>
#       <td>No señala completitud.</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Imputación</td>
#       <td>Identifica que columnas se eliminan y cuales se imputan. Además, identifica el tipo de imputación según distribución simétrica o asimétrica (sesgo) por medio de gráficos.</td>
#       <td>Realiza imputación, sin identificar el tipo según distribución. No incluye gáficos.</td>
#       <td>No realiza imputación o lo hace sin justificación.</td>
#       <td>No realiza imputación ni presenta gráficos.</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Análisis estadístico descriptivo</td>
#       <td>Realiza el análisis estadístico descriptivo de los datos numéricos y de texto.</td>
#       <td>Realiza el análisis estadístico parcial de los datos numéricos y de texto.</td>
#       <td>El análisis incluye solo parte de los datos numéricos, sin interpretación clara.</td>
#       <td>No realiza análisis estadístico o es incorrecto.</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Detección de outliers</td>
#       <td>Identifica outliers utilizando el tipo de gráfico pertinente. Además, explica si se eliminarán o no, argumentando su decisión.</td>
#       <td>Identifica outliers con gráfico adecuado, pero con explicación parcial de su tratamiento.</td>
#       <td>Identifica algunos valores únicos, sin indicar frecuencias ni gráficas.</td>
#       <td>No identifica ni trata outliers.</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Análisis de correlación</td>
#       <td>Realiza el gráfico de correlación y explica qué columnas están correlacionadas.</td>
#       <td>Realiza el gráfico, pero con explicación limitada sobre la relación entre columnas.</td>
#       <td>Presenta un gráfico incompleto o incorrecto, sin interpretación.</td>
#       <td>No realiza análisis de correlación.</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>Top 1, ¿qué pais tuvo la mayor tasa de reproduccion del virus? Campo: reproduction_rate</td>
#       <td>Identifica correctamente el pais mediante código eficiente, indicando claramente el nombre del pais y la cantidad máxima de reproducción del virus.</td>
#       <td>Identifica el pais de mayor tasa de reproduccion del virus, pero el código es poco eficiente o no explicita la cantidad exacta de la tasa de reproducción.</td>
#       <td>Obtiene un listado general de paises o de tasas máximas, pero no logra aislar correctamente el nombre del pais correspondiente.</td>
#       <td>No realiza el cálculo o el resultado y la lógica aplicada son incorrectos.</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>Gráfico de torta, campo: continent</td>
#       <td>Genera un gráfico de torta correcto que muestra la distribución por el campo solicitado, incluyendo etiquetas legibles, porcentajes (autopct) y un título adecuado que facilita su interpretación.</td>
#       <td>Genera el gráfico de torta con la distribución por el campo solicitado, pero omite los porcentajes, las etiquetas o el título descriptivo.</td>
#       <td>Presenta un gráfico de torta confuso, incompleto o utiliza un tipo de gráfico incorrecto para representar la variable.</td>
#       <td>No genera el gráfico o este presenta errores críticos de ejecución en el código.</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>Promedio de la población, campo: population</td>
#       <td>Calcula con precisión el promedio del campo solicitado usando la función correspondiente (mean()) e interpreta correctamente el resultado numérico en el contexto de los datos.</td>
#       <td>Calcula de forma correcta el promedio del campo solicitado, pero no realiza ninguna interpretación ni contextualización del resultado obtenido.</td>
#       <td>Aplica una función estadística incorrecta o el cálculo matemático presenta errores.</td>
#       <td>No realiza el cálculo del promedio.</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>Histograma, para el campo: total_deaths</td>
#       <td>Construye un histograma adecuado para representar la frecuencia del campo solicitado, configurando correctamente los rangos (bins), etiquetas en los ejes y un título claro para el análisis de la distribución.</td>
#       <td>Construye el histograma para el campo requerido, pero carece de títulos, etiquetas en los ejes o la selección de rangos (bins) no permite evaluar bien la forma de la distribución.</td>
#       <td>Presenta una gráfica de barras genérica o un gráfico incompleto que no cumple con las propiedades de un histograma.</td>
#       <td>No genera la visualización o el código arroja error de ejecución.</td>
#     </tr>
#   </tbody>
# </table>
#
# ---
# *Cada dato cuenta una historia, y ustedes tienen el poder de descubrirla. Confíen en su curiosidad, sean rigurosos con su análisis y no tengan miedo de equivocarse: los mejores hallazgos muchas veces nacen de preguntas atrevidas. ¡Vamos equipo, su proyecto puede revelar lo que nadie más ha visto!*
#
# ---

# %% [markdown]
# ## Proyecto: COVID - Análisis exploratorio
#
#
# Usaras el siguiente dataset para realizar el proyecto: **[descargar](https://drive.google.com/file/d/1xPWgeqLWSxCqZYxstHW3sKzbaa02Iuhv/view?usp=sharing)**

# %%
def completitud(df):
    completitud = pd.DataFrame(df.isnull().sum()).reset_index()
    completitud = completitud.rename(columns={"index": "columna", 0: "faltantes"})
    completitud["completitud"] = (1 - completitud["faltantes"] / df.shape[0]) * 100
    completitud = completitud.sort_values(by="completitud", ascending=True)
    completitud.reset_index(drop=True, inplace=True)
    
    return completitud.round()
